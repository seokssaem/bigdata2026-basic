# %% [markdown]
# # JSON
#
# - 자바스크립트로 만들어진 경량의 데이터파일
# - {"key":"value"} --> 파이썬의 딕셔너리와 비슷하다.
# - 변환이 쉽다.

# %%
import json

# %% [markdown]
# - 파이썬으로 딕셔너리 --> json 변환

# %%
dict_list = [
    {
        'name':'james',
        'age':20,
        'spec':[175.5, 70.5]
    },
    {
        'name':'alice',
        'age':21,
        'spec':[168.5, 60.5]
    }
]

# %%
dict_list

# %%
type(dict_list)

# %%
type(dict_list[0])

# %% [markdown]
# ## json으로 변환

# %%
json_string = json.dumps(dict_list)

# %%
json_string

# %%
type(json_string)

# %% [markdown]
# ## json 파일로 저장(json으로 내보내기)

# %%
with open('dictList.json', 'wt') as f:
    f.write(json_string)

# %% [markdown]
# ## json 파일 읽기

# %%
import json

with open('dictList.json', 'rt') as f:
    json_reader = f.read()
    dict_list = json.loads(json_reader) # 파이썬으로 변환

# %%
dict_list
# Out:
# [{'name': 'james', 'age': 20, 'spec': [175.5, 70.5]},
#  {'name': 'alice', 'age': 21, 'spec': [168.5, 60.5]}]

# %%
type(dict_list)
# Out:
# list

# %%
for dic in dict_list:
    print(f'이름 : {dic["name"]}')
    print(f'나이 : {dic["age"]}')
    print(f'키 : {dic["spec"][0]}')
    print(f'몸무게 : {dic["spec"][1]}')
    print('='* 50)
# Out:
# 이름 : james
# 나이 : 20
# 키 : 175.5
# 몸무게 : 70.5
# ...
# 이름 : alice
# 나이 : 21
# 키 : 168.5
# 몸무게 : 60.5
# ...

# %% [markdown]
# ## 실습 - 서울시 마포구의 cctv의 설치목적을 알아보자!

# %%
import json

with open('cctv.json', 'rt', encoding='utf-8') as f:
    buffer = f.read()
    cctv_list = json.loads(buffer) # 파이썬으로 변환
    cctv_purpose = set()  # 결과를 담을 빈 세트를 생성(중복을 없애기 위해)
    for place in cctv_list:
        cctv_purpose.add(place['설치목적구분']) # 세트에 데이터를 추가 (add)

# %%
cctv_list
# Out:
# [{'관리기관명': '서울특별시 마포구청',
#   '소재지지번주소': '서교동 395-43',
#   '설치년월': '2005-07',
#   '보관일수': '30',
#   '카메라대수': '1',
#   '경도': '126.916711',
#   '소재지도로명주소': '양화로 72',
#   '위도': '37.550747',
#   '설치목적구분': '주정차단속',
#   '촬영방면정보': '360도전방면',
#   '데이터기준일자': '2020-05-20',
#   '카메라화소수': '200',
#   '관리기관전화번호': '02-3153-8432'},
#  {'관리기관명': '서울특별시 마포구청',
#   '소재지지번주소': '서교동 395-43',
#   '설치년월': '2005-07',
#   '보관일수': '30',
#   '카메라대수': '1',
#   '경도': '126.916711',
#   '소재지도로명주소': '양화로 72',
#   '위도': '37.550747',
#   '설치목적구분': '주정차단속',
#   '촬영방면정보': '360도전방면',
#   '데이터기준일자': '2020-05-20',
#   '카메라화소수': '200',
#   '관리기관전화번호': '02-3153-8432'},
#  {'관리기관명': '서울특별시 마포구청',
#   '소재지지번주소': '아현동 723-12',
#   '설치년월': '2006-09',
#   '보관일수': '30',
#   '카메라대수': '1',
#   '경도': '126.960721',
#   '소재지도로명주소': '환일길 27',
#   '위도': '37.555943',
#   '설치목적구분': '방범',
#   '촬영방면정보': '360도전방면',
#   '데이터기준일자': '2020-05-20',
#   '카메라화소수': '200',
#   '관리기관전화번호': '02-3153-8432'},
#  {'관리기관명': '서울특별시 마포구청',
# ...

# %%
cctv_purpose
# Out:
# {'방범', '방범(경찰 설치)', '방범(공원)', '방범(그린파킹)', '방범(어린이보호구역)', '방범(치수과)', '주정차단속'}
